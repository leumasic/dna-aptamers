# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_6578/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import gaussian_kde

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=14)          # controls default text sizes
plt.rc('axes', titlesize=14)     # fontsize of the axes title
plt.rc('axes', labelsize=12)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)    # fontsize of the tick labels
plt.rc('ytick', labelsize=14)    # fontsize of the tick labels
plt.rc('legend', fontsize=14)    # legend fontsize
plt.rc('figure', titlesize=14)  # fontsize of the figure title


pd. set_option('display.max_columns', None) # or 1000.
pd. set_option('display.max_rows', None) # or 1000.
pd. set_option('display.max_colwidth', 199) # or 199.

# %%
df1 = pd.read_csv("train_record_updated2.csv")
df2 = pd.read_csv("train_6_log.csv")
df3 = pd.read_csv("train_8.csv")
df = pd.concat([df1, df2, df3])
df["rmse"] = df.min_test_mse.apply(np.sqrt)
df[["EPOCH", "BATCH_SIZE", "LR", "N_HIDDEN_UNITS", "NUM_LAYERS","train_count","min_val_loss_id", "min_val_loss", "min_test_mse_id", "min_test_mse","rmse"]].sort_values("min_test_mse")
# Out:
#     EPOCH  BATCH_SIZE       LR  N_HIDDEN_UNITS  NUM_LAYERS  train_count  \
# 2      70         500  0.01000              20         1.0     350000.0
# 15     70         500  0.01000              20         1.0     350000.0
# 16     60         100  0.00300              20         1.0     350000.0
# 3      60         100  0.00300              20         1.0     350000.0
# 10     60         500  0.00500              20         1.0     350000.0
# 8      60        1500  0.01000              20         1.0     350000.0
# 0      65         500  0.05000              24         1.0     350000.0
# 13     65         500  0.05000              24         1.0     350000.0
# 7      60        1500  0.01000              16         1.0     350000.0
# 14     65         500  0.05000              28         1.0     350000.0
# 1      65         500  0.05000              28         1.0     350000.0
# 12     60          10  0.00300              12         1.0     350000.0
# ...

# %%
df[["EPOCH", "BATCH_SIZE", "LR", "N_HIDDEN_UNITS", "NUM_LAYERS","train_count","min_val_loss_id", "min_val_loss", "min_test_mse_id", "min_test_mse","rmse"]].sort_values("rmse")
# Out:
#     EPOCH  BATCH_SIZE       LR  N_HIDDEN_UNITS  NUM_LAYERS  train_count  \
# 2      70         500  0.01000              20         1.0     350000.0
# 15     70         500  0.01000              20         1.0     350000.0
# 16     60         100  0.00300              20         1.0     350000.0
# 3      60         100  0.00300              20         1.0     350000.0
# 10     60         500  0.00500              20         1.0     350000.0
# 8      60        1500  0.01000              20         1.0     350000.0
# 0      65         500  0.05000              24         1.0     350000.0
# 13     65         500  0.05000              24         1.0     350000.0
# 7      60        1500  0.01000              16         1.0     350000.0
# 14     65         500  0.05000              28         1.0     350000.0
# 1      65         500  0.05000              28         1.0     350000.0
# 12     60          10  0.00300              12         1.0     350000.0
# ...

# %%
result_df1 = pd.read_csv("2022-04-15.csv")
result_df2 = pd.read_csv("2022-04-15_2.csv")
result_df3 = pd.read_csv("2022-04-15_3.csv")
result_df4 = pd.read_csv("2022-04-15_4_mvoymaguil.csv")
result_df5 = pd.read_csv("2022-04-15_5_cwxccvhugl.csv")
result_df6 = pd.read_csv("2022-04-15_5_mbfbkyocyc.csv")
result_df7 = pd.read_csv("2022-04-15_6_mfzrjvfchj.csv")
result_df8 = pd.read_csv("2022-04-15_7_cpehwbpjfn.csv")
result_df9 = pd.read_csv("2022-04-15_8_rufzqirvbg.csv")
result_df10 = pd.read_csv("2022-04-18_1_kmwaskrksi.csv")
result_df11 = pd.read_csv("2022-04-19_0_ymghvykxfd.csv")
# ignore the 2022-04-19_1   1  1
result_df12 = pd.read_csv("2022-04-19_2_ngtheghypr.csv")
result_df13 = pd.read_csv("2022-04-20_2_flopnwudzj.csv")
result_df14 = pd.read_csv("2022-04-29_1_qygkfhythz.csv")
result_df15 = pd.read_csv("2022-04-29_2_oiulumvzxh.csv") # oiulumvzxh
result_df16 = pd.read_csv("2022-05-01_1_nbjbuszzgc.csv") #nbjbuszzgc


result_df = pd.concat([result_df1, result_df2,result_df3,result_df4,result_df5, result_df6, result_df7,result_df8, result_df9,
                       result_df10,result_df11,result_df12,result_df13,result_df14, result_df15, result_df16], ignore_index=True)
result_df["test_rmse"] = result_df.test_mse.apply(np.sqrt)
result_df[["EPOCH","BATCH_SIZE","LR","N_HIDDEN_UNITS","NUM_LAYERS","BI_DIR","data_used_n","min_val_loss_id","min_val_loss","test_mse","test_rmse","note"]].sort_values("test_rmse")
# Out:
#     EPOCH  BATCH_SIZE    LR  N_HIDDEN_UNITS  NUM_LAYERS BI_DIR  data_used_n  \
# 26    150        1500  0.01             120           2   True      1000000
# 14    150        2500  0.01              90           1   True      1000000
# 19    150        2500  0.01              90           1   True      1000000
# 25    150        1500  0.01              90           2   True      1000000
# 18    150        2500  0.01              90           1   True      1000000
# 20    150        2500  0.01              90           1   True      1000000
# 23    150        2500  0.01             120           1   True      1000000
# 21    150        2500  0.01              90           1   True      1000000
# 9     150        2500  0.01              60           1    NaN      1000000
# 13    150        2500  0.01              60           1   True      1000000
# 24    150        2500  0.01              90           2   True      1000000
# ...

# %%
best_row = result_df.loc[26]
to_print = f"LSTM, mse {np.round(best_row.test_mse,3)}, rmse {np.round(np.sqrt(best_row.test_mse),3)}"
title = f"Loss curve of best LSTM Model (RMSE={np.round(np.sqrt(best_row.test_mse),3)} on test data)"
print(title)
# test_rmse = np.array(best_row["rmse"][1:-1].split(", ")).astype(float)
# test_mse = np.array(best_row["test_mse_list"][1:-1].split(", ")).astype(float)
val_loss = np.array(best_row["val_loss_list"][1:-1].split(", ")).astype(float)
train_loss = np.array(best_row["train_loss_list"][1:-1].split(", ")).astype(float)
# x = 

x = np.arange(len(train_loss))
  
# # plot lines
fig = plt.figure(figsize=(9,4)) 
plt.title(title)
plt.plot(x, train_loss, label = "train loss")
plt.plot(x, val_loss, label = "val loss")
plt.legend()
plt.show()
# Out:
# Loss curve of best LSTM Model (RMSE=1.065 on test data)

# %%
df2 = result_df[["EPOCH","BATCH_SIZE","LR","N_HIDDEN_UNITS","NUM_LAYERS","BI_DIR","data_used_n","min_val_loss_id","min_val_loss","test_mse"]]
df2["rmse"] = df2.test_mse.apply(np.sqrt)
df2.BI_DIR.fillna(False, inplace=True)
df2.sort_values("rmse")
# Out:
# /tmp/ipykernel_6578/4100503775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["rmse"] = df2.test_mse.apply(np.sqrt)
# /tmp/ipykernel_6578/4100503775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.BI_DIR.fillna(False, inplace=True)
#     EPOCH  BATCH_SIZE    LR  N_HIDDEN_UNITS  NUM_LAYERS  BI_DIR  data_used_n  \
# 26    150        1500  0.01             120           2    True      1000000
# 14    150        2500  0.01              90           1    True      1000000
# ...

# %%
df2[df2.BI_DIR == False].sort_values("rmse")
# Out:
#     EPOCH  BATCH_SIZE    LR  N_HIDDEN_UNITS  NUM_LAYERS  BI_DIR  data_used_n  \
# 9     150        2500  0.01              60           1   False      1000000
# 8     150        2500  0.01              42           1   False      1000000
# 10    150        2500  0.01              42           1   False      1000000
# 6     150        2500  0.01              36           1   False      1000000
# 7     150        2500  0.01              28           2   False      1000000
# 5     100        2500  0.01              28           1   False      1000000
# 4     100        2500  0.01              24           1   False      1000000
# 2      70        1500  0.01              24           1   False      1000000
# 0      70        1500  0.01              20           1   False      1000000
# 3      80        2500  0.01              20           1   False      1000000
# 1      70         500  0.01              20           1   False      1000000
# ...

# %%
best_row = result_df.loc[26]
to_print = f"LSTM, mse {np.round(best_row.test_mse,3)}, rmse {np.round(np.sqrt(best_row.test_mse),3)}"
title = f"LSTM, rmse {np.round(np.sqrt(best_row.test_mse),3)}"
print(title)
# test_rmse = np.array(best_row["rmse"][1:-1].split(", ")).astype(float)
# test_mse = np.array(best_row["test_mse_list"][1:-1].split(", ")).astype(float)
val_loss = np.array(best_row["val_loss_list"][1:-1].split(", ")).astype(float)[1:108]
train_loss = np.array(best_row["train_loss_list"][1:-1].split(", ")).astype(float)[1:108]
# x = 

x = np.arange(len(train_loss))
  
# # plot lines
fig = plt.figure(figsize=(10,5)) 
plt.title(title)
plt.plot(x, train_loss, label = "train loss")
plt.plot(x, val_loss, label = "val loss")
plt.legend()
plt.show()
# Out:
# LSTM, rmse 1.065

# %%
# data_org = pd.read_csv("./data/1mill_dataset.csv", names=["strand","energy"],dtype={0: str, 1: float})
# data_org.head(50)

# %%
earlydf = df[["EPOCH", "BATCH_SIZE", "LR", "N_HIDDEN_UNITS", "NUM_LAYERS","train_count","min_val_loss_id", "min_val_loss", "min_test_mse_id", "min_test_mse","rmse"]].sort_values("rmse").copy()
earlydf.columns = ["EPOCH","BATCH_SIZE","LR","N_HIDDEN_UNITS","NUM_LAYERS","data_used_n","min_val_loss_id","min_val_loss","min_test_mse_id","test_mse","test_rmse"]
earlydf.data_used_n.fillna(200000, inplace=True)
earlydf
# Out:
#     EPOCH  BATCH_SIZE       LR  N_HIDDEN_UNITS  NUM_LAYERS  data_used_n  \
# 2      70         500  0.01000              20         1.0     350000.0
# 15     70         500  0.01000              20         1.0     350000.0
# 16     60         100  0.00300              20         1.0     350000.0
# 3      60         100  0.00300              20         1.0     350000.0
# 10     60         500  0.00500              20         1.0     350000.0
# 8      60        1500  0.01000              20         1.0     350000.0
# 0      65         500  0.05000              24         1.0     350000.0
# 13     65         500  0.05000              24         1.0     350000.0
# 7      60        1500  0.01000              16         1.0     350000.0
# 14     65         500  0.05000              28         1.0     350000.0
# 1      65         500  0.05000              28         1.0     350000.0
# 12     60          10  0.00300              12         1.0     350000.0
# ...

# %%
laterdf = result_df[["EPOCH","BATCH_SIZE","LR","N_HIDDEN_UNITS","NUM_LAYERS","BI_DIR","data_used_n","min_val_loss_id","min_val_loss","test_mse","test_rmse","note"]].sort_values("test_rmse").copy()
laterdf.BI_DIR.fillna(False, inplace=True)
laterdf
# Out:
#     EPOCH  BATCH_SIZE    LR  N_HIDDEN_UNITS  NUM_LAYERS  BI_DIR  data_used_n  \
# 26    150        1500  0.01             120           2    True      1000000
# 14    150        2500  0.01              90           1    True      1000000
# 19    150        2500  0.01              90           1    True      1000000
# 25    150        1500  0.01              90           2    True      1000000
# 18    150        2500  0.01              90           1    True      1000000
# 20    150        2500  0.01              90           1    True      1000000
# 23    150        2500  0.01             120           1    True      1000000
# 21    150        2500  0.01              90           1    True      1000000
# 9     150        2500  0.01              60           1   False      1000000
# 13    150        2500  0.01              60           1    True      1000000
# 24    150        2500  0.01              90           2    True      1000000
# ...

# %%
alldf = pd.concat([earlydf, laterdf])
alldf.BI_DIR.fillna(False, inplace=True)
alldf.reset_index(inplace=True)
alldf = alldf[["EPOCH","BATCH_SIZE","LR","N_HIDDEN_UNITS","NUM_LAYERS","BI_DIR","data_used_n","min_val_loss_id","min_val_loss","test_mse","test_rmse","note"]].sort_values("test_rmse")
alldf.loc[alldf.min_val_loss == 1.0, "min_val_loss"]= None
alldf.loc[alldf.min_val_loss.isnull(), "min_val_loss_id"]= None

alldf
# Out:
#     EPOCH  BATCH_SIZE       LR  N_HIDDEN_UNITS  NUM_LAYERS  BI_DIR  \
# 45    150        1500  0.01000             120         2.0    True
# 46    150        2500  0.01000              90         1.0    True
# 47    150        2500  0.01000              90         1.0    True
# 48    150        1500  0.01000              90         2.0    True
# 49    150        2500  0.01000              90         1.0    True
# 50    150        2500  0.01000              90         1.0    True
# 51    150        2500  0.01000             120         1.0    True
# 52    150        2500  0.01000              90         1.0    True
# 53    150        2500  0.01000              60         1.0   False
# 54    150        2500  0.01000              60         1.0    True
# 55    150        2500  0.01000              90         2.0    True
# 56    150        2500  0.01000              90         1.0    True
# 58    150        2500  0.01000              42         1.0   False
# ...

# %%
alldf.dtypes
# Out:
# EPOCH              int64
# BATCH_SIZE         int64
# LR                 float64
# N_HIDDEN_UNITS     int64
# NUM_LAYERS         float64
# BI_DIR             bool
# data_used_n        float64
# min_val_loss_id    float64
# min_val_loss       float64
# test_mse           float64
# test_rmse          float64
# note               object
# dtype: object

# %%
# for ele in alldf.loc[: ,"test_rmse"] :
#      print(ele)

# %%
finaldf = alldf[alldf["test_rmse"].isin([1.0653867962018213,1.0839401450288022,1.0913384043614505,1.1065415019752471,1.111913237250264,\
                                         1.1184134285754361,1.6743268863912701,1.5117546370315171,1.3530560952588808,1.1290210807471537])]\
[["EPOCH","BATCH_SIZE","LR","N_HIDDEN_UNITS","NUM_LAYERS","BI_DIR","data_used_n","test_rmse","note"]]

finaldf.drop_duplicates(inplace=True)
finaldf
# Out:
#     EPOCH  BATCH_SIZE       LR  N_HIDDEN_UNITS  NUM_LAYERS  BI_DIR  \
# 45    150        1500  0.01000             120         2.0    True
# 46    150        2500  0.01000              90         1.0    True
# 47    150        2500  0.01000              90         1.0    True
# 49    150        2500  0.01000              90         1.0    True
# 50    150        2500  0.01000              90         1.0    True
# 52    150        2500  0.01000              90         1.0    True
# 53    150        2500  0.01000              60         1.0   False
# 0      70         500  0.01000              20         1.0   False
# 20     60        1000  0.00100              12         1.0   False
# 44     30          20  0.00005              16         1.0   False
#
#     data_used_n  test_rmse  \
# 45    1000000.0   1.065387
# 46    1000000.0   1.083940
# 47    1000000.0   1.091338
# 49    1000000.0   1.106542
# 50    1000000.0   1.111913
# 52    1000000.0   1.118413
# 53    1000000.0   1.129021
# ...

# %%
finaldf.columns = ["Epoch","Batch","LR","Hid_units","N_Layers","Bi_Dir","Data_Size","Test_rmse","Note"]

rmse_note = {1.0653867962018213: "Best performance model. 2 grains feature engineering as input, 2 final neural network layers",
             1.0839401450288022: "2nd best model. Model (bi_directional LSTM) with Hyperparameter tuning on 1M data.",
             1.0913384043614505: "Modified 2nd best model, Add extra layer at LSTM output neural network",
             1.1065415019752471: "Modified 2nd best model, Add extra input features (length/max_length, A_count/length, etc.)",
             1.111913237250264: "Modified 2nd best model, Add extra input features (length/max_length, A_count/length, etc.), Add extra layer at LSTM output neural network",
             1.1184134285754361: "Modified 2nd best model, feature engineering (3-grain) , Add another layer at output neural network.",
             1.1290210807471537: "Model tuning result on 1M data",
             1.3530560952588808: "Model tuning result on 0.35M data",
             1.5117546370315171: "Applied new Feature engineering: Reverse DNA strand as new datapoint,“AGCT”=“TCGA”,double the training data",
             1.6743268863912701: "Benchmark: Model tuning on 0.2M data"
             }



finaldf.Note = finaldf.Test_rmse.map(rmse_note)

from IPython.display import display, HTML

def wrap_df_text(df):
    return display(HTML(df.to_html().replace("\\n","<br>")))

finaldf['Note'] = finaldf['Note'].str.wrap(50)
wrap_df_text(finaldf)
# display(finaldf)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Epoch</th>
#       <th>Batch</th>
#       <th>LR</th>
#       <th>Hid_units</th>
#       <th>N_Layers</th>
#       <th>Bi_Dir</th>
#       <th>Data_Size</th>
#       <th>Test_rmse</th>
#       <th>Note</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>45</th>
#       <td>150</td>
#       <td>1500</td>
#       <td>0.01000</td>
#       <td>120</td>
#       <td>2.0</td>
#       <td>True</td>
#       <td>1000000.0</td>
#       <td>1.065387</td>
#       <td>Best performance model. 2 grains feature<br>engineering as input, 2 final neural network<br>layers</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>150</td>
#       <td>2500</td>
#       <td>0.01000</td>
#       <td>90</td>
#       <td>1.0</td>
#       <td>True</td>
#       <td>1000000.0</td>
#       <td>1.083940</td>
# ...
